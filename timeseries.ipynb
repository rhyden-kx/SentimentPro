# %%
# !pip install dash_bootstrap_components
# Out:
# Requirement already satisfied: dash_bootstrap_components in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (1.5.0)
# Requirement already satisfied: dash>=2.0.0 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash_bootstrap_components) (2.16.1)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (3.0.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (3.0.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.20.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (6.8.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (4.8.0)
# Requirement already satisfied: requests in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (2.31.0)
# Requirement already satisfied: retrying in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (1.5.8)
# Requirement already satisfied: setuptools in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.0.0->dash_bootstrap_components) (58.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (1.7.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from importlib-metadata->dash>=2.0.0->dash_bootstrap_components) (3.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (8.2.3)
# Requirement already satisfied: packaging in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (21.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from Werkzeug<3.1->dash>=2.0.0->dash_bootstrap_components) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from requests->dash>=2.0.0->dash_bootstrap_components) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from requests->dash>=2.0.0->dash_bootstrap_components) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from requests->dash>=2.0.0->dash_bootstrap_components) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from requests->dash>=2.0.0->dash_bootstrap_components) (2023.7.22)
# Requirement already satisfied: six>=1.7.0 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from retrying->dash>=2.0.0->dash_bootstrap_components) (1.16.0)
# Requirement already satisfied: colorama in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash>=2.0.0->dash_bootstrap_components) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aiko\appdata\local\programs\python\python39\lib\site-packages (from packaging->plotly>=5.0.0->dash>=2.0.0->dash_bootstrap_components) (3.0.6)

# %%
import dash
import dash_bootstrap_components as dbc
from dash import dcc, html
from dash.dependencies import Input, Output
import random
import plotly.express as px
import plotly.graph_objs as go
import pandas as pd

# %% [markdown]
# Topics

# %%
def plot_default_graph():
    # Merge the dataframes
    all_data = data.merge(topic_df, on='review', how='inner')

    # Clean the date
    all_data['date_clean'] = pd.to_datetime(all_data['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
    all_data['date_clean'] = all_data['date_clean'].combine_first(pd.to_datetime(all_data['date'], format='%Y-%m-%dT%H:%M:%S.%fZ', errors='coerce'))
    all_data['date_clean'] = all_data['date_clean'].astype(str).str[:10]
    all_data['date_clean'] = pd.to_datetime(all_data['date_clean']).dt.date

    # Select columns needed
    df = all_data[['review', 'date_clean', 'Topic_Name', 'Topic_Number']]
    get_topic_name = {
        0: 'App Responsiveness', 1: 'Money Growth (Interest Rates)', 2: 'Customer Services',
        3: 'Services & Products', 4: 'User Interface', 5: 'Credit card',
        6: 'Login & Account Setup', 7: 'Competition', 8: 'Safety', 9: 'Customer trust'
    }

    # Split reviews with multiple topics into duplicates of single topics
    df['Topic_Number'] = df['Topic_Number'].astype(str)
    df2 = df[df['Topic_Number'].str.contains(',', regex=False)].copy()

    # Hard coding cos splitting by regex is killing me
    df['Topic_Number'] = df['Topic_Number'].str[0]
    df['Topic_Number'] = df['Topic_Number'].astype(int)
    df['Topic_Name'] = df['Topic_Number'].map(get_topic_name)

    df2['Topic_Number'] = df2['Topic_Number'].str[2]
    df2['Topic_Number'] = df2['Topic_Number'].astype(int)
    df2['Topic_Name'] = df2['Topic_Number'].map(get_topic_name)

    df = pd.concat([df, df2])

    # Group by topic, number, and date
    df = df.groupby(['Topic_Name', 'Topic_Number', 'date_clean']).size().reset_index(name='num_reviews')

    # Select date range
    s = df.date_clean.iloc[5]
    e = df.date_clean.iloc[10]

    # Create the default graph
    topics_over_time = px.line(df, 'date_clean', 'num_reviews', color='Topic_Name',
                               labels={"date_clean": "Date", "num_reviews": "Number of Reviews", "Topic_Name": "Topic"},
                               title="Number of Reviews by Topics over time")
    # Update date range
    topics_over_time.update_xaxes(range=[s, e])

    return topics_over_time

def get_date_range():
    # Merge the dataframes
    all_data = data.merge(topic_df, on='review', how='inner')

    # Clean the date
    all_data['date_clean'] = pd.to_datetime(all_data['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
    all_data['date_clean'] = all_data['date_clean'].combine_first(pd.to_datetime(all_data['date'], format='%Y-%m-%dT%H:%M:%S.%fZ', errors='coerce'))
    all_data['date_clean'] = all_data['date_clean'].astype(str).str[:10]

    min_date = all_data.date_clean.min()
    max_date = all_data.date_clean.max()
    return [min_date, max_date]

# %% [markdown]
# Issues

# %%
import os
os.chdir("C:/Users/rhyde/SentimentPro/Data")

app_responsiveness = pd.read_csv('App Responsiveness.csv')
competition = pd.read_csv('Competition.csv')
credit_card = pd.read_csv('Credit card.csv')
customer_service = pd.read_csv('Customer Services.csv')
customer_trust = pd.read_csv('Customer trust.csv')
login_account = pd.read_csv('Login & Account Setup.csv')
money_growth = pd.read_csv('Money Growth (Interest Rates).csv')
safety = pd.read_csv('Safety.csv')
service_products = pd.read_csv('Services & Products.csv')
user_interface = pd.read_csv('User Interface.csv')
data = pd.read_csv('combined_data.csv')

# %%
# Test
topics = ['', 'App Responsiveness', 'Competition', 'Credit Card Usage', 'Customer Services', 'Customer Trust',
          'Login & Account Setup', 'Money Growth (Interest Rates)', 'Safety', 'Service Products', 'User Interface']

datasets = {
    'App Responsiveness': app_responsiveness,
    'Competition': competition,
    'Credit Card Usage': credit_card,
    'Customer Services': customer_service,
    'Customer Trust': customer_trust,
    'Login & Account Setup': login_account,
    'Money Growth (Interest Rates)': money_growth,
    'Safety': safety,
    'Service Products': service_products,
    'User Interface': user_interface
}

# Issue method
def issue(data, df):
    # Merge the two DataFrames on the 'review' column
    merged = pd.merge(data, df, on='review', how='inner')
    # Drop the 'Unnamed: 0' column
    merged.drop(columns=['Unnamed: 0'], inplace=True)
    # Rename the 'key' column to 'issue'
    merged.rename(columns={'key': 'issue'}, inplace=True)
    # Convert 'date' column to datetime format
    merged['date'] = pd.to_datetime(merged['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
    # If the previous conversion fails, try a different format
    merged['date'] = merged['date'].combine_first(pd.to_datetime(merged['date'], format='%Y-%m-%dT%H:%M:%S.%fZ', errors='coerce'))
    # Convert 'date' column to string
    merged['date'] = merged['date'].astype(str)
    # Extract date only (YYYY-MM-DD)
    merged['date_only'] = merged['date'].str[:10]
    grouped_data = merged.groupby(['date_only', 'issue']).size().reset_index(name='count')
    # Convert 'date_only' to datetime if it's not already in datetime format
    grouped_data['date_only'] = pd.to_datetime(grouped_data['date_only'])
    # Aggregate data by month and issue
    grouped_data['month_year'] = grouped_data['date_only'].dt.to_period('M')
    monthly_data = grouped_data.groupby(['month_year', 'issue']).size().reset_index(name='count')
    # Calculate total count for each issue
    issue_totals = monthly_data.groupby('issue')['count'].sum().sort_values(ascending=False)
    # Select top n issues
    top_issues = issue_totals.head(5).index
    return top_issues 

# Initialize an empty dictionary to store the top issues for each topic
issues = {}

# Call preprocess for each key in the datasets dictionary
for topic, df in datasets.items():
    top_issues = issue(data, df)
    issues[topic] = top_issues

# %%
def preprocess(data, df):
    # Merge the two DataFrames on the 'review' column
    merged = pd.merge(data, df, on='review', how='inner')

    # Drop the 'Unnamed: 0' column
    merged.drop(columns=['Unnamed: 0'], inplace=True)

    # Rename the 'key' column to 'issue'
    merged.rename(columns={'key': 'issue'}, inplace=True)

    # Convert 'date' column to datetime format
    merged['date'] = pd.to_datetime(merged['date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')

    # If the previous conversion fails, try a different format
    merged['date'] = merged['date'].combine_first(pd.to_datetime(merged['date'], format='%Y-%m-%dT%H:%M:%S.%fZ', errors='coerce'))

    # Convert 'date' column to string
    merged['date'] = merged['date'].astype(str)

    # Extract date only (YYYY-MM-DD)
    merged['date_only'] = merged['date'].str[:10]

    return merged

def plot_top_n_issues_time_series(merged_data):
    # Create a time series line plot
    grouped_data = merged_data.groupby(['date_only', 'issue']).size().reset_index(name='count')

    # Convert 'date_only' to datetime if it's not already in datetime format
    grouped_data['date_only'] = pd.to_datetime(grouped_data['date_only'])

    # Aggregate data by month and issue
    grouped_data['month_year'] = grouped_data['date_only'].dt.to_period('M')
    monthly_data = grouped_data.groupby(['month_year', 'issue']).size().reset_index(name='count')

    # Calculate total count for each issue
    issue_totals = monthly_data.groupby('issue')['count'].sum().sort_values(ascending=False)

    # Select top n issues
    top_issues = issue_totals.head(5).index

    # Filter monthly_data for top n issues
    monthly_data_top = monthly_data[monthly_data['issue'].isin(top_issues)]

    # Convert 'month_year' to string format
    monthly_data_top.loc[:, 'month_year'] = monthly_data_top['month_year'].astype(str)

    # Create a time series line plot
    fig = px.line(monthly_data_top, x='month_year', y='count', color='issue', title=f'Number of Reviews by Top 5 Issues Over Time')
    
    # Add markers to the lines
    for trace in fig.data:
        trace.update(mode='lines+markers')
    fig.update_xaxes(title_text='Month')
    fig.update_yaxes(title_text='Number of Reviews')
    fig.update_yaxes(fixedrange=True)
    return fig

# %%
# Dash app
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

data = pd.read_csv('combined_data.csv')
topic_df = pd.read_csv('topics_review.csv')

# Issues page layout
issues_layout = html.Div(
    [
        html.H1("Issues Faced"),
        html.H3("Select an issue to view details"),
        html.Br(),
        dcc.DatePickerRange(
            id='date_picker_range',
            min_date_allowed=get_date_range()[0],
            max_date_allowed=get_date_range()[1],
            initial_visible_month=get_date_range()[0],
            end_date=get_date_range()[1]),
        html.Br(),
        dcc.Dropdown(
            id="topic-dropdown",
            options=[{"label": topic, "value": topic} for topic in topics],
            value=topics[0],
        ),
        dcc.Graph(id="issues-line-chart"),
    ]
)

# App layout
app.layout = issues_layout

def update_date_range(fig, start_date, end_date):
    if start_date is None:
        start_date = get_date_range()[0]
    if end_date is None:
        end_date = get_date_range()[1]
    fig.update_xaxes(range=[start_date,end_date])
    return fig

@app.callback(
    Output("issues-line-chart", "figure"),
    [Input("topic-dropdown", "value"),
    Input('date_picker_range', 'start_date'),
    Input('date_picker_range', 'end_date')]
)
def update_issues_page(topic,start_date,end_date):
    if not topic:  # Check if topic is None or empty string
        # Return default graph
        default_fig = plot_default_graph()
        update_date_range(default_fig,start_date,end_date)
        return default_fig
    else:
        print(f"Selected topic: {topic}")
        # Define a dictionary mapping topics to their respective DataFrames
        topic_to_df = {
            'App Responsiveness': app_responsiveness,
            'Competition': competition,
            'Credit Card Usage': credit_card,
            'Customer Services': customer_service,
            'Customer Trust': customer_trust,
            'Login & Account Setup': login_account,
            'Money Growth (Interest Rates)': money_growth,
            'Safety': safety,
            'Service Products': service_products,
            'User Interface': user_interface
        }

        # Get the DataFrame for the selected topic
        df = topic_to_df[topic]
        cleaned_df = preprocess(data, df)
        # Call plot_top_n_issues_time_series function to generate the figure
        fig = plot_top_n_issues_time_series(cleaned_df)
        update_date_range(fig,start_date,end_date)
        return fig
    
if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
# Selected topic: Credit Card Usage
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\dash\_callback.py:491, in register_callback.<locals>.wrap_func.<locals>.add_context(
#     *args=('Credit Card Usage', None, '2024-03-10'),
#     **kwargs={}
# )
#     490 try:
# --> 491     jsonResponse = to_json(response)
#         response = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#     492 except TypeError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\dash\_utils.py:26, in to_json(
#     value={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})}
# )
#      24 from plotly.io.json import to_json_plotly
# ---> 26 return to_json_plotly(value)
#         value = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\io\_json.py:142, in to_json_plotly(
#     plotly_object={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})},
#     pretty=False,
#     engine='json'
# )
#     139     from _plotly_utils.utils import PlotlyJSONEncoder
#     141     return _safe(
# --> 142         json.dumps(plotly_object, cls=PlotlyJSONEncoder, **opts), _swap_json
#         opts = {'separators': (',', ':')}
#         _swap_json = (('<', '\\u003c'), ('>', '\\u003e'), ('/', '\\u002f'))
#         plotly_object = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#     143     )
#     144 elif engine == "orjson":
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\json\__init__.py:238, in dumps(
#     obj={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})},
#     skipkeys=False,
#     ensure_ascii=True,
#     check_circular=True,
#     allow_nan=True,
#     cls=<class '_plotly_utils.utils.PlotlyJSONEncoder'>,
#     indent=None,
#     separators=(',', ':'),
#     default=None,
#     sort_keys=False,
#     **kw={}
# )
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#         cls = <class '_plotly_utils.utils.PlotlyJSONEncoder'>
#         ensure_ascii = True
#         skipkeys = False
#         check_circular = True
#         allow_nan = True
#         indent = None
#         separators = (',', ':')
#         default = None
#         sort_keys = False
#         obj = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#         kw = {}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\_plotly_utils\utils.py:56, in PlotlyJSONEncoder.encode(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})}
# )
#      55 # this will raise errors in a normal-expected way
# ---> 56 encoded_o = super(PlotlyJSONEncoder, self).encode(o)
#         o = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#         self = <_plotly_utils.utils.PlotlyJSONEncoder object at 0x0000018D4C599BA0>
#      57 # Brute force guessing whether NaN or Infinity values are in the string
#      58 # We catch false positive cases (e.g. strings such as titles, labels etc.)
#      59 # but this is ok since the intention is to skip the decoding / reencoding
#      60 # step when it's completely safe
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\json\encoder.py:199, in JSONEncoder.encode(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})}
# )
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#         o = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#         self = <_plotly_utils.utils.PlotlyJSONEncoder object at 0x0000018D4C599BA0>
#     200 if not isinstance(chunks, (list, tuple)):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\json\encoder.py:257, in JSONEncoder.iterencode(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})},
#     _one_shot=True
# )
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#         _iterencode = <_json.Encoder object at 0x0000018D4C5B55A0>
#         o = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\_plotly_utils\utils.py:133, in PlotlyJSONEncoder.default(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     obj=Period('2022-09', 'M')
# )
#     132         pass
# --> 133 return _json.JSONEncoder.default(self, obj)
#         self = <_plotly_utils.utils.PlotlyJSONEncoder object at 0x0000018D4C599BA0>
#         obj = Period('2022-09', 'M')
#         _json = <module 'json' from 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib\\json\\__init__.py'>
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\json\encoder.py:179, in JSONEncoder.default(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o=Period('2022-09', 'M')
# )
#     161 """Implement this method in a subclass such that it returns
#     162 a serializable object for ``o``, or calls the base implementation
#     163 (to raise a ``TypeError``).
#    (...)
#     177
#     178 """
# --> 179 raise TypeError(f'Object of type {o.__class__.__name__} '
#         o = Period('2022-09', 'M')
#     180                 f'is not JSON serializable')
#
# TypeError: Object of type Period is not JSON serializable
#
# During handling of the above exception, another exception occurred:
#
# InvalidCallbackReturnValue                Traceback (most recent call last)
# InvalidCallbackReturnValue: The callback for `<Output `issues-line-chart.figure`>`
#                 returned a value having type `Figure`
#                 which is not JSON serializable.
#
#
# The value in question is either the only value returned,
# or is in the top level of the returned list,
#
#                 and has string representation
#                 `Figure({
#     'data': [{'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2022-09', 'M'), Period('2022-10', 'M'), Period('2022-12', 'M'),
#                           Period('2023-06', 'M'), Period('2023-07', 'M'), Period('2023-11', 'M'),
#                           Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 4, 5, 1, 1, 1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with deposit func' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with deposit function',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with deposit function',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-11', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Complaints about staff a' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Complaints about staff asking for positive reviews',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Complaints about staff asking for positive reviews',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Confusion about app auth' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Confusion about app authenticity',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Confusion about app authenticity',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })`
#
#                 In general, Dash properties can only be
#                 dash components, strings, dictionaries, numbers, None,
#                 or lists of those.
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:25: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Selected topic: Customer Services
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\dash\_callback.py:491, in register_callback.<locals>.wrap_func.<locals>.add_context(
#     *args=('Customer Services', None, '2024-03-10'),
#     **kwargs={}
# )
#     490 try:
# --> 491     jsonResponse = to_json(response)
#         response = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': ('issue=Lack of transparency and' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Lack of transparency and access to funds',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Lack of transparency and access to funds',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-01', 'M'), Period('2023-07', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Request for SingPass sig' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Request for SingPass sign in feature',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Request for SingPass sign in feature',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-02', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with GXS apps lin' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with GXS apps linked to Grab app',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with GXS apps linked to Grab app',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Authenticity concerns<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Authenticity concerns',
#               'line': {'color': '#FFA15A', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Authenticity concerns',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#     492 except TypeError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\dash\_utils.py:26, in to_json(
#     value={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})}
# )
#      24 from plotly.io.json import to_json_plotly
# ---> 26 return to_json_plotly(value)
#         value = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': ('issue=Lack of transparency and' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Lack of transparency and access to funds',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Lack of transparency and access to funds',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-01', 'M'), Period('2023-07', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Request for SingPass sig' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Request for SingPass sign in feature',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Request for SingPass sign in feature',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-02', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with GXS apps lin' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with GXS apps linked to Grab app',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with GXS apps linked to Grab app',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Authenticity concerns<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Authenticity concerns',
#               'line': {'color': '#FFA15A', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Authenticity concerns',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\plotly\io\_json.py:142, in to_json_plotly(
#     plotly_object={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})},
#     pretty=False,
#     engine='json'
# )
#     139     from _plotly_utils.utils import PlotlyJSONEncoder
#     141     return _safe(
# --> 142         json.dumps(plotly_object, cls=PlotlyJSONEncoder, **opts), _swap_json
#         opts = {'separators': (',', ':')}
#         _swap_json = (('<', '\\u003c'), ('>', '\\u003e'), ('/', '\\u002f'))
#         plotly_object = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': ('issue=Lack of transparency and' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Lack of transparency and access to funds',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Lack of transparency and access to funds',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-01', 'M'), Period('2023-07', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Request for SingPass sig' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Request for SingPass sign in feature',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Request for SingPass sign in feature',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-02', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with GXS apps lin' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with GXS apps linked to Grab app',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with GXS apps linked to Grab app',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Authenticity concerns<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Authenticity concerns',
#               'line': {'color': '#FFA15A', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Authenticity concerns',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
# ...
#               'mode': 'lines+markers',
#               'name': 'Request for SingPass sign in feature',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-02', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with GXS apps lin' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with GXS apps linked to Grab app',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with GXS apps linked to Grab app',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Authenticity concerns<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Authenticity concerns',
#               'line': {'color': '#FFA15A', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Authenticity concerns',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#         self = <_plotly_utils.utils.PlotlyJSONEncoder object at 0x0000018D4C59A620>
#     200 if not isinstance(chunks, (list, tuple)):
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\json\encoder.py:257, in JSONEncoder.iterencode(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o={'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart'...e, 'title': {'text': 'Number of Reviews'}}}
# })}})},
#     _one_shot=True
# )
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#         _iterencode = <_json.Encoder object at 0x0000018D4C5B79A0>
#         o = {'multi': True, 'response': defaultdict(<class 'dict'>, {'issues-line-chart': {'figure': Figure({
#     'data': [{'hovertemplate': ('issue=Lack of transparency and' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Lack of transparency and access to funds',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Lack of transparency and access to funds',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-01', 'M'), Period('2023-07', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Request for SingPass sig' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Request for SingPass sign in feature',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Request for SingPass sign in feature',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-02', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with GXS apps lin' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with GXS apps linked to Grab app',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with GXS apps linked to Grab app',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Authenticity concerns<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Authenticity concerns',
#               'line': {'color': '#FFA15A', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Authenticity concerns',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })}})}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\_plotly_utils\utils.py:133, in PlotlyJSONEncoder.default(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     obj=Period('2023-01', 'M')
# )
#     132         pass
# --> 133 return _json.JSONEncoder.default(self, obj)
#         self = <_plotly_utils.utils.PlotlyJSONEncoder object at 0x0000018D4C59A620>
#         obj = Period('2023-01', 'M')
#         _json = <module 'json' from 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\\lib\\json\\__init__.py'>
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\json\encoder.py:179, in JSONEncoder.default(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o=Period('2023-01', 'M')
# )
#     161 """Implement this method in a subclass such that it returns
#     162 a serializable object for ``o``, or calls the base implementation
#     163 (to raise a ``TypeError``).
#    (...)
#     177
#     178 """
# --> 179 raise TypeError(f'Object of type {o.__class__.__name__} '
#         o = Period('2023-01', 'M')
#     180                 f'is not JSON serializable')
#
# TypeError: Object of type Period is not JSON serializable
#
# During handling of the above exception, another exception occurred:
#
# InvalidCallbackReturnValue                Traceback (most recent call last)
# InvalidCallbackReturnValue: The callback for `<Output `issues-line-chart.figure`>`
#                 returned a value having type `Figure`
#                 which is not JSON serializable.
#
#
# The value in question is either the only value returned,
# or is in the top level of the returned list,
#
#                 and has string representation
#                 `Figure({
#     'data': [{'hovertemplate': ('issue=Lack of transparency and' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Lack of transparency and access to funds',
#               'line': {'color': '#636efa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Lack of transparency and access to funds',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-01', 'M'), Period('2023-07', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1, 1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Request for SingPass sig' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Request for SingPass sign in feature',
#               'line': {'color': '#EF553B', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Request for SingPass sign in feature',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-02', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': ('issue=Issues with GXS apps lin' ... '}<br>count=%{y}<extra></extra>'),
#               'legendgroup': 'Issues with GXS apps linked to Grab app',
#               'line': {'color': '#00cc96', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Issues with GXS apps linked to Grab app',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Others<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Others',
#               'line': {'color': '#ab63fa', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Others',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2023-12', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'},
#              {'hovertemplate': 'issue=Authenticity concerns<br>month_year=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'Authenticity concerns',
#               'line': {'color': '#FFA15A', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'lines+markers',
#               'name': 'Authenticity concerns',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array([Period('2024-01', 'M')], dtype=object),
#               'xaxis': 'x',
#               'y': array([1], dtype=int64),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'title': {'text': 'issue'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Number of Reviews by Top 5 Issues Over Time'},
#                'xaxis': {'anchor': 'y',
#                          'domain': [0.0, 1.0],
#                          'range': [2022-09-03, 2024-03-10],
#                          'title': {'text': 'Month'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'fixedrange': True, 'title': {'text': 'Number of Reviews'}}}
# })`
#
#                 In general, Dash properties can only be
#                 dash components, strings, dictionaries, numbers, None,
#                 or lists of those.
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:25: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:20: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:25: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\rhyde\AppData\Local\Temp\ipykernel_20552\3786855593.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
